# %%
import numpy as np
import pandas as pd
data=pd.read_csv("/content/insurance.csv")
data
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'expenses'], dtype='object')

# %%
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
data.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   expenses  1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe()
# Out:
#                age          bmi     children      expenses
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.665471     1.094918  13270.422414
# std      14.049960     6.098382     1.205493  12110.011240
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4740.287500
# 50%      39.000000    30.400000     1.000000   9382.030000
# 75%      51.000000    34.700000     2.000000  16639.915000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
import seaborn as sns
sns.heatmap(data.isna())

# %%
data.corr()
# Out:
#                age       bmi  children  expenses
# age       1.000000  0.109341  0.042469  0.299008
# bmi       0.109341  1.000000  0.012645  0.198576
# children  0.042469  0.012645  1.000000  0.067998
# expenses  0.299008  0.198576  0.067998  1.000000

# %%
sns.heatmap(data.corr())

# %%
sns.jointplot(x='expenses',y='age',data=data,kind='reg')

# %%
sns.boxplot(x=data.age)

# %%
sns.histplot(x=data.expenses)

# %%
sns.histplot(x=data.bmi)

# %%
sns.histplot(x='expenses',data=data,hue='smoker')

# %%
print(data['smoker'].value_counts())
sns.countplot(x=data.smoker)
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
print(data['age'].value_counts())
sns.countplot(x=data.age)
# Out:
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: age, dtype: int64

# %%
print(data['children'].value_counts())
sns.countplot(x=data.children)
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
print(data['sex'].value_counts())
sns.countplot(x=data.sex)
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
sns.barplot(x='sex',y='expenses',data=data)

# %%
sns.barplot(x='children',y='expenses',data=data)

# %%
x=data.iloc[:,:-1]
y=data.iloc[:,-1]
x
# Out:
#       age     sex   bmi  children smoker     region
# 0      19  female  27.9         0    yes  southwest
# 1      18    male  33.8         1     no  southeast
# 2      28    male  33.0         3     no  southeast
# 3      33    male  22.7         0     no  northwest
# 4      32    male  28.9         0     no  northwest
# ...   ...     ...   ...       ...    ...        ...
# 1333   50    male  31.0         3     no  northwest
# 1334   18  female  31.9         0     no  northeast
# 1335   18  female  36.9         0     no  southeast
# 1336   21  female  25.8         0     no  southwest
# 1337   61  female  29.1         0    yes  northwest
#
# [1338 rows x 6 columns]

# %%
y
# Out:
# 0       16884.92
# 1        1725.55
# 2        4449.46
# 3       21984.47
# 4        3866.86
#           ...
# 1333    10600.55
# 1334     2205.98
# 1335     1629.83
# 1336     2007.95
# 1337    29141.36
# Name: expenses, Length: 1338, dtype: float64

# %%
dum=pd.get_dummies(x[['smoker','region','sex']],drop_first=True)

# %%
x=pd.concat([x,dum],axis=1)
x
# Out:
#       age     sex   bmi  children smoker     region  smoker_yes  \
# 0      19  female  27.9         0    yes  southwest           1
# 1      18    male  33.8         1     no  southeast           0
# 2      28    male  33.0         3     no  southeast           0
# 3      33    male  22.7         0     no  northwest           0
# 4      32    male  28.9         0     no  northwest           0
# ...   ...     ...   ...       ...    ...        ...         ...
# 1333   50    male  31.0         3     no  northwest           0
# 1334   18  female  31.9         0     no  northeast           0
# 1335   18  female  36.9         0     no  southeast           0
# 1336   21  female  25.8         0     no  southwest           0
# 1337   61  female  29.1         0    yes  northwest           1
#
#       region_northwest  region_southeast  region_southwest  sex_male
# 0                    0                 0                 1         0
# ...

# %%
x=x.drop(columns=['sex','region','smoker'])

# %%
x
# Out:
#       age   bmi  children  smoker_yes  region_northwest  region_southeast  \
# 0      19  27.9         0           1                 0                 0
# 1      18  33.8         1           0                 0                 1
# 2      28  33.0         3           0                 0                 1
# 3      33  22.7         0           0                 1                 0
# 4      32  28.9         0           0                 1                 0
# ...   ...   ...       ...         ...               ...               ...
# 1333   50  31.0         3           0                 1                 0
# 1334   18  31.9         0           0                 0                 0
# 1335   18  36.9         0           0                 0                 1
# 1336   21  25.8         0           0                 0                 0
# 1337   61  29.1         0           1                 1                 0
#
#       region_southwest  sex_male
# 0                    1         0
# ...

# %%
x.dtypes
# Out:
# age                   int64
# bmi                 float64
# children              int64
# smoker_yes            uint8
# region_northwest      uint8
# region_southeast      uint8
# region_southwest      uint8
# sex_male              uint8
# dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 4.60137921e+03,  1.28742750e+04,  1.25749114e+04,  1.31873438e+04,
#         6.28647991e+02,  3.23600579e+04,  1.28500634e+04,  1.22735263e+04,
#         3.85416238e+03,  2.99011883e+04,  1.10178822e+04,  1.74311342e+04,
#         8.65622158e+03,  8.35717194e+03,  3.35876793e+03,  1.03165559e+04,
#         3.99602560e+03,  6.86618161e+03,  1.49817493e+04,  1.44000975e+04,
#         1.25002522e+04,  3.32708180e+04,  9.16294032e+03,  8.96876860e+03,
#         3.19426444e+03,  8.19279066e+03,  9.36719844e+03,  1.08363702e+04,
#         7.69513277e+03,  4.44786928e+03,  1.40737281e+04,  5.76116682e+03,
#         3.46768270e+04,  2.74988610e+04,  3.35430860e+04,  9.54530067e+03,
#         3.08003705e+04,  2.68188651e+04,  1.52237398e+04,  3.42180293e+04,
#         6.39634574e+03,  1.40613197e+04,  1.06005954e+04,  1.49654165e+04,
#         4.19213099e+03,  1.29975644e+04,  4.49734994e+03,  2.90631419e+04,
# ...

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
score
# Out:
# 0.7406005660648991
